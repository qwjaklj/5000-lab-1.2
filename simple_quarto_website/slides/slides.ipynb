# %% [raw]
# ---
# title: "Quarto Slides"
# author: "Yicheng Zhu"
# format:
#   revealjs:
#     slide-number: true
#     chalkboard:
#       buttons: false
#     preview-links: auto
#     code-fold: true
#     code-summary: "Show the code"
# bibliography: ../reference.bib
# ---
#
# ## Citation
# - As discussed in [@gaich20153d], ...
#
# ## Image
# - ![](../images/photo1.jpg){.border width="300"}
# ![](../images/photo2.jpg){.border width="300"}
#
# ## Code
# ```{.python}
# import matplotlib.pyplot as plt
# plt.plot([1, 2, 3], [1, 4, 9])
# plt.show()
# ```
#
# ## Outcome

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3], [1, 4, 9])
plt.show()

# %% [raw]
# # Slides 5
